# %%
import numpy as np
import os
import cv2

# %%
cd /content/drive/My Drive/Course/CS230/SEM raw images
# Out:
# /content/drive/My Drive/Course/CS230/SEM raw images

# %%
path = '/content/drive/My Drive/Course/CS230/SEM raw images/jpg/*.jpg'

# %%
from skimage.io import imread_collection

# %%
images = imread_collection(path)

# %%
len(images)
# Out:
# 47

# %%
for i in range(len(images)):
  img = images[i]
  crop_img = img[0:350, 0:350]
  resize = cv2.resize(crop_img,(224,224))
  cv2.imwrite("224image_"+str(i)+".jpg", resize)

# %%
path = '/content/drive/My Drive/Course/CS230/SEM raw images/CropRaw(224x224)/*.jpg'
images = imread_collection(path)

# %%
for i in range(len(images)):
  print(images[i].shape)
# Out:
# (471, 512)
# (471, 512)
# (471, 512)
# (471, 512)
# (471, 512)
# (471, 512)
# (943, 1024)
# (471, 512)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (1887, 2048)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)
# (943, 1024)

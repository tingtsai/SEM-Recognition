# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

# %%
pwd
# Out:
# '/Users/chingtingtsai/Google Drive/Code/SEM shape'

# %%
img = cv2.imread('NanoV.png')

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (312, 312, 3)

# %%
hist = cv2.calcHist([img],[0],None,[312],[0,312])
hist.shape
# Out:
# (312, 1)

# %%
plt.hist(img.ravel(),312); 
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
for i in range(gray.shape[0]):    
    for j in range(gray.shape[1]):
        if (gray[i][j] < 50):
            gray[i][j] = 0
        else:
            gray[i][j] = 1

# %%
hist = cv2.calcHist([gray],[0],None,[312],[0,312])
plt.hist(gray.ravel(),312); 
plt.show()

# %%
plt.imshow(img)

# %%
One = img


kernel = np.ones((3, 3), np.uint8) 
One = cv2.erode(One, kernel,iterations = 10)
One = cv2.morphologyEx(One, cv2.MORPH_OPEN, kernel,iterations = 5)

plt.imshow(One)

# %%
cv2.imwrite('erode.png', One)
# Out:
# True

# %%
filter = [1,1,1],[1,0,1],[1,1,1]

# %%
def Etching(gray, t):

    
    for t in range(time):
    for i in range(gray.shape[0]):
        for j in range(gray.shape[1]):


            v = [[img[i-1][j-1], img[i-1][j], img[i-1][j+1]], 
                [img[i][j-1], img[i][j], img[i][j+1]],
                [img[i+1][j-1], img[i+1][j], img[i+1][j+1]]]0

            conv = np.convolv(v, filter)
            vel = 8 - conv

            t = 1/vel
            
            
            if (conv < 400):
